# %%
from PIL import Image

# %%
bob=Image.open("images.jpg")
bob
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x274C3161F0>

# %%
bob.show()

# %%
bob.size
# Out:
# (300, 168)

# %%
bob.format
# Out:
# 'JPEG'

# %%
bob.mode
# Out:
# 'RGB'

# %%
w,h=bob.size

# %%
w
# Out:
# 300

# %%
w*h
# Out:
# 50400

# %%
bob.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x2ED6612160>

# %%
bob.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=300x168 at 0x2ED4A20E50>

# %%
bob
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x2ED4C79910>

# %%
bob.rotate(20)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0xE509F85370>

# %%
bob.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0xE2B81D0070>

# %%
bob.resize((200,100))
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0xE2B6B93FA0>

# %%
crop_box=(158,30,270,130)

# %%
bob_face=bob.crop(crop_box)
bob_face
# Out:
# <PIL.Image.Image image mode=RGB size=112x100 at 0xDACB6FD730>

# %%
small_image=bob.resize((w//2,h//2))
small_image
# Out:
# <PIL.Image.Image image mode=RGB size=150x84 at 0xE509BC3BE0>

# %%
small_image.size
# Out:
# (150, 84)

# %%
bob.resize((w*3,h*3))
# Out:
# <PIL.Image.Image image mode=RGB size=900x504 at 0xE509BE9700>

# %% [markdown]
# # Home Work

# %%
Work=Image.open("image2.jpg")
Work
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1260x360 at 0xE509BEEEB0>

# %%
Work.size
# Out:
# (1260, 360)

# %%
Instagram=Work.crop((50,25,360,335))
Instagram
# Out:
# <PIL.Image.Image image mode=RGB size=310x310 at 0xE509BF4100>

# %%
crop_box3=(473,25,785,335)

# %%
Facebook=Work.crop(crop_box3)
Facebook
# Out:
# <PIL.Image.Image image mode=RGB size=312x310 at 0xDACAA280D0>

# %%
crop_box4=(900,25,1210,335)

# %%
Twitter=Work.crop(crop_box4)
Twitter
# Out:
# <PIL.Image.Image image mode=RGB size=310x310 at 0xDACAA339D0>

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'adding_Text.ipynb',
#  'download (1).jpg',
#  'font.ttf',
#  'image2.jpg',
#  'images.jpg',
#  'loadingImages.ipynb',
#  'loadingImagesh.ipynb']

# %%
image_path=[]
for f in os.listdir('C:\Users\ASUS\Desktop\PYTHON\image_processing'):
    if f.endswith('.jpg'):
        image_path.append('C:\Users\ASUS\Desktop\PYTHON\image_processing'+f)
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_84/1251937294.py", line 2
#     for f in os.listdir('C:\Users\ASUS\Desktop\PYTHON\image_processing'):
#                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
image_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_84/2711015976.py in <module>
# ----> 1 image_path
#
# NameError: name 'image_path' is not defined
