# %%
from PIL import Image, ImageDraw,ImageFont

# %%
DB=Image.open("images.jpg")
DB
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x665A449880>

# %%
drawble=ImageDraw.Draw(DB)

# %%
myfont=ImageFont.truetype("font.ttf",30)

# %%
drawble.text((50,5),"bob!! the cutie",(255,0,0),font=myfont)

# %%
DB
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x665A449880>
